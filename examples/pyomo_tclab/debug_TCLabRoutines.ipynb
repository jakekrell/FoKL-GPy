# %% [markdown]
# For debugging development of *TClabRoutines.py*.

# %%
from TCLabRoutines import TCLab
import os

# %%
files = ["step_tests", "step_tests2"]

# %%
filenames = []
for file in files:
    filenames.append(os.path.join(dir, "data", file + ".csv"))

# %%
my_class = TCLab(filenames)
