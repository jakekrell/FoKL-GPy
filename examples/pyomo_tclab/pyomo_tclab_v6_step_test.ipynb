# %% [markdown]
# # <h1 style="text-align: center;">Optimal Control of TCLab using a Gaussian process regression embedded in Pyomo - notebook v6</h1>
#
# <p style="text-align: center;">Alex Dowling<sup>a</sup>, Jacob P. Krell<sup>b</sup>, David S. Mebane<sup>b</sup>
#
# <p style="text-align: center;"><sup>a</sup>Department of Chemical and Biomolecular Engineering, University of Notre Dame, Notre Dame, IN 46556, USA <br>
# <sup>b</sup>Department of Mechanical and Aerospace Engineering, West Virginia University, Morgantown, WV, 26506-6106, USA</p>
#
# ## Method
#
# - fit GP to raw data as a smoothing function
# - take derivative of smoothed data, which is possible via chain rule of GP analytic gradient
# - fit GP to derivative, which is the "GP Model" of TCLab
# - integrate GP to validate model of derivative
#
# ## Change Log
# - This files is derived from `pyomo_tclab_v6.ipynb`
# - Removed lag for control signal `Q` to simplify first Pyomo implementation.
#
# ## Setup

# %%
import os
dir = os.path.abspath('')  # directory of notebook
import pandas as pd
import numpy as np
from FoKL import FoKLRoutines
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %% [markdown]
# Load and parse data:

# %%
#filename = "tclab_sine_test.csv"
filename = "tclab_step_test.csv"
data = pd.read_csv(os.path.join(dir, filename))

tvec = data["Time"].values
Q1 = data["Q1"].values
TS1 = data["T1"].values

# %%
len(tvec)
# Out:
# 901

# %% [markdown]
# Define heater power control signal:

# %%
Q1f = interp1d(tvec, Q1, kind='previous')  # piecewise Q1

# sine test
#dQ1f_analytic = lambda t: 1500 * np.cos(30 * np.pi * t / tvec[-1]) * np.pi / tvec[-1]  # derivative of analytic Q1

# step test
dQ1f_analytic = lambda t: np.zeros(len(t))  # derivative of analytic Q1

dQ1f = interp1d(tvec, dQ1f_analytic(tvec), kind='previous')  # piecewise derivative of analytic Q1

# %%
tvec_ub = tvec[1::] - 1e-3  # upper bounds for piecewise plots
tvec_piecewise = [tvec[0]]
for i in range(len(tvec_ub)):
    tvec_piecewise += [tvec_ub[i], tvec[i + 1]]
tvec_piecewise = np.array(tvec_piecewise)

fig, axs = plt.subplots(2, 1, sharex=True)
fig.suptitle("Piecewise Control Signal")
fig.supxlabel("Time (s)")

axs[0].plot(tvec, Q1, 'o')
axs[0].plot(tvec_piecewise, Q1f(tvec_piecewise), '--')
axs[0].set_ylabel("Q1 (%)")
axs[0].set_xlim([0, tvec[-1] / 15 / 4])
axs[0].legend(["Measured"])
axs[0].grid()

axs[1].plot(tvec, dQ1f_analytic(tvec), 'o')
axs[1].plot(tvec_piecewise, dQ1f(tvec_piecewise), '--')
axs[1].set_ylabel("d(Q1)/dt (%/s)")
axs[1].set_xlim([0, tvec[-1] / 15 / 4])
axs[1].legend(["via Analytic Derivative"])
axs[1].grid()

# %% [markdown]
# ## Benchmark
#
# Predicting temperatures via the two-state ODE,

# %%
alpha = 0.00016                                                                     # watts / (units P1 * percent U1)
P1 = 200                                                                            # P1 units
T_amb = TS1[0]  # ambient temperature

IC = [T_amb, T_amb]  # initial condition of states [TH1, TS1]
CpH =  7.006         # J/degC
CpS = 0.01           # J/degC
Ua =  0.051          # W/degC
Ub =  0.001          # W/degC

# %%
def dy_benchmark(t, y):
    """Benchmark ODE, for TS1."""
    TH1, TS1 = y
    dTH1 = (Ua * (T_amb - TH1) + Ub * (TS1 - TH1) + alpha * P1 * Q1f(t)) / CpH
    dTS1 = Ub * (TH1 - TS1) / CpS
    return [dTH1, dTS1]

soln_benchmark = solve_ivp(dy_benchmark, [tvec[0], tvec[-1]], IC, t_eval=tvec)

# %%
TS1_benchmark = soln_benchmark.y[1]

# %matplotlib inline
plt.figure()
plt.plot(tvec, TS1)
plt.plot(tvec, TS1_benchmark)
plt.grid()
plt.title('ODE Benchmark Solution')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (°C)')
_ = plt.legend(['Measured', 'Benchmark'])

# %% [markdown]
# ## Derivative of Smoothed Data
#
# Since raw measurements are noisy, a smoothing functions is applied before calculating the time derivative.
#
# ### Smoothing
#
# Using a GP as the smoothing function,

# %%
GP_T = FoKLRoutines.FoKL(kernel=1, UserWarnings=False)
_ = GP_T.fit([tvec, Q1], TS1, clean=True)
# Out:
# [1, 3824.7843450245336]
# [2, 5725.823708968146]
# [2, 2281.8172458427034]
# [3, 3247.6460585965765]
# [3, 5709.510075584221]
# [4, 4648.002731430089]

# %%
TS1_smooth = GP_T.evaluate()

# %matplotlib inline
plt.figure()
plt.plot(tvec, TS1)
plt.plot(tvec, TS1_smooth)
plt.grid()
plt.title('Smoothed Measurements')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (°C)')
_ = plt.legend(['Measured', 'Smoothed'])

# %% [markdown]
# ### Derivative
#
# Applying the chain rule to obtain training data,

# %%
dGP = GP_T.bss_derivatives()  # gradient of GP_T

dGPdt = interp1d(tvec, dGP[:, 0])
dGPdQ1 = interp1d(Q1, dGP[:, 1])
dTS1f = lambda t: dGPdt(t) + dGPdQ1(Q1f(t)) * dQ1f(t)  # interpolation function

dTS1 = dTS1f(tvec)  # evaluate interpolation function at tvec to form training data
# Out:
# /Users/adowling/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/FoKL/FoKLRoutines.py:603: RuntimeWarning: divide by zero encountered in scalar divide
#   phi[n, m, di] *= self.evaluate_basis(c, X[n, md], kernel=kernel, d=derp) \
# /Users/adowling/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/FoKL/FoKLRoutines.py:611: RuntimeWarning: invalid value encountered in add
#   dy[:,n,m,di] = dy[:,n,m,di] + betas[-draws:,b+1]*phi[n,m,di]  # update after md loop

# %% [markdown]
# Validating training data:

# %%
# %matplotlib inline
plt.figure()
plt.plot(tvec, dTS1)
plt.title('Derivative of Smoothed Measurements')
plt.xlabel('Time (s)')
plt.ylabel('Temperature / Time (°C/s)')
plt.legend(['Training Data'])
plt.grid()

# %%
def dy_training(t, y):
    """ODE to integrate GP's training data'."""
    return [dTS1f(t)]

soln_training = solve_ivp(dy_training, [tvec[0], tvec[-1]], [TS1_smooth[0]], t_eval=tvec)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/numpy/core/numerictypes.py:320, in issubclass_(arg1, arg2)
#     319 try:
# --> 320     return issubclass(arg1, arg2)
#     321 except TypeError:
#
# TypeError: issubclass() arg 1 must be a class
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       2     """ODE to integrate GP's training data'."""
#       3     return [dTS1f(t)]
# ----> 5 soln_training = solve_ivp(dy_training, [tvec[0], tvec[-1]], [TS1_smooth[0]], t_eval=tvec)
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py:602, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     600 status = None
#     601 while status is None:
# --> 602     message = solver.step()
#     604     if solver.status == 'finished':
#     605         status = 0
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py:64, in rk_step(fun, t, y, f, h, A, B, C, K)
#      62 for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63     dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64     K[s] = fun(t + c * h, y + dy)
#      66 y_new = y + h * np.dot(K[:-1].T, B)
#      67 f_new = fun(t + h, y_new)
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# Cell In[13], line 3, in dy_training(t, y)
#       1 def dy_training(t, y):
#       2     """ODE to integrate GP's training data'."""
# ----> 3     return [dTS1f(t)]
#
# Cell In[11], line 5, in <lambda>(t)
#       3 dGPdt = interp1d(tvec, dGP[:, 0])
#       4 dGPdQ1 = interp1d(Q1, dGP[:, 1])
# ----> 5 dTS1f = lambda t: dGPdt(t) + dGPdQ1(Q1f(t)) * dQ1f(t)  # interpolation function
#       7 dTS1 = dTS1f(tvec)
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/scipy/interpolate/_polyint.py:79, in _Interpolator1D.__call__(self, x)
#      58 def __call__(self, x):
#      59     """
#      60     Evaluate the interpolant
#      61
#    (...)
#      77
#      78     """
# ---> 79     x, x_shape = self._prepare_x(x)
#      80     y = self._evaluate(x)
#      81     return self._finish_y(y, x_shape)
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/scipy/interpolate/_polyint.py:91, in _Interpolator1D._prepare_x(self, x)
#      89 def _prepare_x(self, x):
#      90     """Reshape input x array to 1-D"""
# ---> 91     x = _asarray_validated(x, check_finite=False, as_inexact=True)
#      92     x_shape = x.shape
#      93     return x.ravel(), x_shape
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/scipy/_lib/_util.py:245, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     243         raise ValueError('object arrays are not supported')
#     244 if as_inexact:
# --> 245     if not np.issubdtype(a.dtype, np.inexact):
#     246         a = toarray(a, dtype=np.float_)
#     247 return a
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/numpy/core/numerictypes.py:416, in issubdtype(arg1, arg2)
#     357 @set_module('numpy')
#     358 def issubdtype(arg1, arg2):
#     359     r"""
#     360     Returns True if first argument is a typecode lower/equal in type hierarchy.
#     361
#    (...)
#     414
#     415     """
# --> 416     if not issubclass_(arg1, generic):
#     417         arg1 = dtype(arg1).type
#     418     if not issubclass_(arg2, generic):
#
# File ~/opt/anaconda3/envs/FoKL/lib/python3.10/site-packages/numpy/core/numerictypes.py:320, in issubclass_(arg1, arg2)
#     285 """
#     286 Determine if a class is a subclass of a second class.
#     287
#    (...)
#     317
#     318 """
#     319 try:
# --> 320     return issubclass(arg1, arg2)
#     321 except TypeError:
#     322     return False
#
# KeyboardInterrupt:

# %%
TS1_training = soln_training.y[0]

# %matplotlib inline
plt.figure()
plt.plot(tvec, TS1_smooth)
plt.plot(tvec, TS1_training)
plt.grid()
plt.title('Integral of Training Data')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (°C)')
_ = plt.legend(['Smoothed', 'via Training Data'])

# %% [markdown]
# ## GP Model of Derivative
#
# ### Training with no lag

# %%
GP_dT = FoKLRoutines.FoKL(kernel=1, UserWarnings=False, aic=True)
print("Training with no lag:")
GP_dT.fit([TS1, Q1], dTS1, clean=True)

# %%
dTS1_GP = GP_dT.evaluate()

# %% [markdown]
# Plot results with no lag

# %%
# %matplotlib inline
plt.figure()
plt.plot(tvec, dTS1)
plt.plot(tvec, dTS1_GP)
plt.title(f"Derivative of Smoothed Measurements, GP Model, Lag = {0} dt")
plt.xlabel('Time (s)')
plt.ylabel('Temperature / Time (°C/s)')
plt.legend(['Training Data', 'GP Model'])
plt.grid()

# %% [markdown]
# ### Integration

# %%
def dy_GP(t, y):
    """ODE to integrate GP of derivative."""
    # Debuging attempt: removed SingleInstance=True
    return [GP_dT.evaluate([y[0], Q1f(t)], clean=True)[0]]


soln_GP = solve_ivp(
    fun=dy_GP, 
    t_span=[tvec[0], tvec[-1]], 
    y0 = [TS1_smooth[0]], 
    method='LSODA', 
    t_eval=tvec)

# %%
TS1_dGP = soln_GP.y[0]

# %matplotlib inline
plt.figure()
plt.plot(tvec, TS1_smooth)
plt.plot(tvec, TS1_training)
plt.plot(tvec, TS1_dGP)
plt.title('Integral of Derivative')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (°C)')
plt.legend(['Smoothed', 'via Training Data', 'via GP Model'])
plt.grid()

# %% [markdown]
# Repeat, but with fixed time step (actually max timestep):

# %%
soln_GP_fixed_dt = solve_ivp(
    fun=dy_GP, 
    t_span= [tvec[0], tvec[-1]], 
    y0=[TS1_smooth[0]], 
    method='LSODA', 
    t_eval=tvec, 
    max_step=1)

# %%
TS1_dGP_fixed_dt = soln_GP_fixed_dt.y[0]

# %matplotlib inline
plt.figure()
plt.plot(tvec, TS1_smooth)
plt.plot(tvec, TS1_training)
plt.plot(tvec, TS1_dGP_fixed_dt)
plt.title('Integral of Derivative')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (°C)')
plt.legend(['Smoothed', 'via Training Data', 'via GP Model (fixed dt)'])
plt.grid()

# %% [markdown]
# Numerically integrate with forward Euler. This is close to the method we will use with Pyomo:

# %%
# Initialize vector to store forward Euler solution
soln_GP_forward_euler = np.zeros(len(TS1_smooth))

# Initialize vector to store GP evaluations
dTS1_GP = np.zeros(len(TS1_smooth)-1)

# Initial condition
soln_GP_forward_euler[0] = TS1_smooth[0]

# Forward Euler integration
# Loop over all of the time points except the last one
for i, t in enumerate(tvec[:-1]):

    # Calculate time step
    dt = tvec[i + 1] - tvec[i]

    # Evaluate GP model at current time
    dTS1_GP[i] = GP_dT.evaluate([soln_GP_forward_euler[i], Q1f(t)], clean=True)[0]

    # Take the forward Euler step
    soln_GP_forward_euler[i+1] = soln_GP_forward_euler[i] + dTS1_GP[i] * dt

# %%
# %matplotlib inline
plt.figure()
plt.plot(tvec, TS1_smooth)
plt.plot(tvec, TS1_training)
plt.plot(tvec, soln_GP_forward_euler)
plt.title('Integral of Derivative')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (°C)')
plt.legend(['Smoothed', 'via Training Data', 'via GP Model (forward Euler)'])
plt.grid()
